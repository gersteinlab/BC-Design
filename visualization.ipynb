# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

colors = [
    "#1F77B4",  # Muted Blue
    "#FF7F0E",  # Vivid Orange
    "#2CA02C",  # Forest Green
    "#D62728",  # Crimson Red
    "#9467BD",  # Lavender Purple
    "#8C564B",  # Cocoa Brown
    "#E377C2",  # Soft Pink
    "#7F7F7F",  # Neutral Gray
    "#BCBD22",  # Olive Yellow
    "#17BECF",  # Aqua Cyan
    "#AEC7E8",  # Light Blue
    "#FFBB78",  # Peach Orange
    "#98DF8A",  # Mint Green
    "#FF9896",  # Coral Pink
    "#C5B0D5",  # Pastel Purple
    "#C49C94",  # Sandy Beige
    "#F7B6D2",  # Light Rose Pink
    "#DBDB8D",  # Soft Yellow
    "#9EDAE5",  # Light Sky Blue
    "#393B79"   # Deep Navy Blue
]

# %% [markdown]
# ## cath 4.2 test set

# %% [markdown]
# # recovery rate

# %%
# ours: 88.04453015327454
# DIPRoT: 50.6
# ProteinMPNN: 50.8 / 45.96 / 49.87 / 45.16
# GVP-GNN: 40.2 / 39.47
# Structured Transformer: 36.4
# StructGNN: 35.91
# GraphTrans: 35.82
# GCA: 37.64
# AlphaDesign: 41.31
# PiFold: 51.66 / 51.51
# GRADE-IF: 52.21
# SPDesign: 67.05
# SPIN-CGNN: 54.81
# LM-Design: 55.65
# ESM-IF: 42.39
# VFN-IF: 54.74
# VFN-IF+: 57.14
# VFN-IFE: 62.67
# ESM-IF1: 55.25
# ProRefiner+ESM-IF1: 57.84
# Knowledge-Design: 60.77
# MMDesign: 54.88
    
# Data for the bar chart
data = {
    "ours": 88.04,
    "DIPRoT": 50.6,
    "ProteinMPNN": 50.8,
    "GVP-GNN": 40.2,
    "Structured Transformer": 36.4,
    "StructGNN": 35.91,
    "GraphTrans": 35.82,
    "GCA": 37.64,
    "AlphaDesign": 41.31,
    "PiFold": 51.66,
    "GRADE-IF": 52.21,
    "SPDesign": 67.05,
    "SPIN-CGNN": 54.81,
    "LM-Design": 55.65,
    "ESM-IF": 42.39,
    "VFN-IFE": 62.67,
    "ESM-IF1": 55.25,
    "ProRefiner+ESM-IF1": 57.84,
    "Knowledge-Design": 60.77,
    "MMDesign": 54.88
}

# Sort the data by values
sorted_data = dict(sorted(data.items(), key=lambda item: item[1], reverse=True))

# Setting the figure size
plt.figure(figsize=(12, 8))

# Create the barplot
ax = sns.barplot(x=list(sorted_data.keys()), y=list(sorted_data.values()), palette=[colors[0]] * len(sorted_data))

# Set the x-axis labels to rotate by 90 degrees
plt.xticks(rotation=90)

# Add labels and title
plt.xlabel("Model")
plt.ylabel("Recovery")
# plt.title("Comparison of Model Performance")

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points')

# Make the plot layout tighter
plt.tight_layout()

# Show the plot
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_1100363/1138512960.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(sorted_data.keys()), y=list(sorted_data.values()), palette=[colors[0]] * len(sorted_data))

# %% [markdown]
# ## perplexity

# %%
# ours: 1.4822756730657707
# DIPRoT: 4.82
# ProteinMPNN: 4.74 / 4.61 / 5.25
# GVP-GNN: 5.29 / 5.36
# Structured Transformer: 6.85
# StructGNN: 6.40
# GraphTrans: 6.63
# GCA: 6.05
# AlphaDesign: 6.30
# PiFold: 4.55
# SurfPro: 3.31
# ESM-IF1: 6.44
# GRADE-IF: 4.35
# SPDesign: 2.43
# SPIN-CGNN: 4.05
# LM-Design: 4.52
# VFN-IF: 4.17
# VFN-IF+: 3.66
# VFN-IFE: 3.36
# Knowledge-Design: 3.46
# MMDesign: 3.86
# New data for the bar chart
data_2 = {
    "ours": 1.48,
    "DIPRoT": 4.82,
    "ProteinMPNN": 4.61,
    "GVP-GNN": 5.29,
    "Structured Transformer": 6.85,
    "StructGNN": 6.40,
    "GraphTrans": 6.63,
    "GCA": 6.05,
    "AlphaDesign": 6.30,
    "PiFold": 4.55,
    "SurfPro": 3.31,
    "ESM-IF1": 6.44,
    "GRADE-IF": 4.35,
    "SPDesign": 2.43,
    "SPIN-CGNN": 4.05,
    "LM-Design": 4.52,
    "VFN-IFE": 3.36,
    "Knowledge-Design": 3.46,
    "MMDesign": 3.86
}

# Sort the data by values
sorted_data_2 = dict(sorted(data_2.items(), key=lambda item: item[1], reverse=False))

# Setting the figure size
plt.figure(figsize=(12, 8))

# Create the barplot using the second color in the list
ax = sns.barplot(x=list(sorted_data_2.keys()), y=list(sorted_data_2.values()), palette=[colors[1]] * len(sorted_data_2))

# Set the x-axis labels to rotate by 90 degrees
plt.xticks(rotation=90)

# Add labels and title
plt.xlabel("Model")
plt.ylabel("Perplexity")
# plt.title("Comparison of Model Error Rates")

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points')

# Make the plot layout tighter
plt.tight_layout()

# Show the plot
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'perplexity.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_1100363/1322851551.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(sorted_data_2.keys()), y=list(sorted_data_2.values()), palette=[colors[1]] * len(sorted_data_2))

# %% [markdown]
# ## nssr

# %%
# ours: 93.23769807815552
# GVP-GNN: 60.81
# ProteinMPNN: 60.56
# ProteinMPNN-C: 63.79
# ESM-IF1: 71.56
# ProRefiner+ESM-IF1: 74.11

# New data for the bar chart
data_3 = {
    "ours": 93.24,
    "GVP-GNN": 60.81,
    "ProteinMPNN": 60.56,
    "ProteinMPNN-C": 63.79,
    "ESM-IF1": 71.56,
    "ProRefiner+ESM-IF1": 74.11
}

# Sort the data by values
sorted_data_3 = dict(sorted(data_3.items(), key=lambda item: item[1], reverse=True))

# Setting the figure size
plt.figure(figsize=(10, 6))

# Create the barplot using the second color in the list (vivid orange)
ax = sns.barplot(x=list(sorted_data_3.keys()), y=list(sorted_data_3.values()), palette=[colors[2]] * len(sorted_data_3))

# Set the x-axis labels to rotate by 90 degrees
plt.xticks(rotation=90)

# Add labels and title
plt.xlabel("Model")
plt.ylabel("nssr")
# plt.title("Comparison of Model Accuracy")

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points')

# Make the plot layout tighter
plt.tight_layout()

# Show the plot
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'nssr.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_1100363/586922383.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(sorted_data_3.keys()), y=list(sorted_data_3.values()), palette=[colors[2]] * len(sorted_data_3))

# %% [markdown]
# ## TM-score

# %%
# cath 4.2 82
# ours: 0.7609036564826965
# StructTrans: 0.72
# GVP: 0.73
# ProteinMPNN: 0.80
# PiFold: 0.71
# ByProt: 0.73
# AF-Design: 0.53
# ESM-Design: 0.38

# New data for the bar chart
data_4 = {
    "ours": 0.76,
    "StructTrans": 0.72,
    "GVP": 0.73,
    "ProteinMPNN": 0.80,
    "PiFold": 0.71,
    "ByProt": 0.73,
    "AF-Design": 0.53,
    "ESM-Design": 0.38
}

# Sort the data by values
sorted_data_4 = dict(sorted(data_4.items(), key=lambda item: item[1], reverse=True))

# Setting the figure size
plt.figure(figsize=(10, 6))

# Create the barplot using the third color in the list (forest green)
ax = sns.barplot(x=list(sorted_data_4.keys()), y=list(sorted_data_4.values()), palette=[colors[3]] * len(sorted_data_4))

# Set the x-axis labels to rotate by 90 degrees
plt.xticks(rotation=90)

# Add labels and title
plt.xlabel("Model")
plt.ylabel("scTM")

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points')

# Make the plot layout tighter
plt.tight_layout()

# Show the plot
# plt.show()
# Path to save the figure
save_path = './figures/cath42_82'
file_name = 'sctm.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_1100363/1069770300.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(sorted_data_4.keys()), y=list(sorted_data_4.values()), palette=[colors[3]] * len(sorted_data_4))

# %%
# cath 4.2
# ours: 0.83
# LM-DESIGN (w/ ProtMPNN encoder): 0.88
# DPLM (w/ ProtMPNN encoder): 0.88

# %% [markdown]
# ## pLDDT

# %%
# cath 4.2 82
# ours: 74.92213845252991
# StructTrans: 68.85
# GVP: 69.67
# ProteinMPNN: 76.53
# PiFold: 67.55
# ByProt: 72.12
# AF-Design: 61.37
# ESM-Design: 59.65

# New data for the bar chart
data_5 = {
    "ours": 74.92,
    "StructTrans": 68.85,
    "GVP": 69.67,
    "ProteinMPNN": 76.53,
    "PiFold": 67.55,
    "ByProt": 72.12,
    "AF-Design": 61.37,
    "ESM-Design": 59.65
}

# Sort the data by values
sorted_data_5 = dict(sorted(data_5.items(), key=lambda item: item[1], reverse=True))

# Setting the figure size
plt.figure(figsize=(10, 6))

# Create the barplot using the fourth color in the list (Crimson Red)
ax = sns.barplot(x=list(sorted_data_5.keys()), y=list(sorted_data_5.values()), palette=[colors[4]] * len(sorted_data_5))

# Set the x-axis labels to rotate by 90 degrees
plt.xticks(rotation=90)

# Add labels and title
plt.xlabel("Model")
plt.ylabel("pLDDT")

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points')

# Make the plot layout tighter
plt.tight_layout()

# Show the plot
# plt.show()
# Path to save the figure
save_path = './figures/cath42_82'
file_name = 'plddt.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_1100363/4000827862.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(sorted_data_5.keys()), y=list(sorted_data_5.values()), palette=[colors[4]] * len(sorted_data_5))

# %%
# cath 4.2
# ours: 81.87
# LM-DESIGN (w/ ProtMPNN encoder): 77.07
# DPLM (w/ ProtMPNN encoder): 77.12

# %% [markdown]
# # Validation on partitioned datasets

# %% [markdown]
# ## cath 4.2

# %%
import pandas as pd

# Specify the path to the CSV file
file_path = './test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/test_results.csv'

# Read the CSV file
data = pd.read_csv(file_path)

# Merge the "FewSecondaryStructures" and "Other" classes into "Other"
data['CATH_Class'] = data['CATH_Class'].replace(['FewSecondaryStructures', 'Other'], 'Other')

# Map "AlphaBeta" to "Alpha Beta" for display purposes
data['CATH_Class'] = data['CATH_Class'].replace({'AlphaBeta': 'Alpha Beta'})

# Display the DataFrame
data.head()
# Out:
#    Recovery      NSSR  pLDDT_CA     pLDDT       RMSD  TMScore  CATH_Class  \
# 0  0.905660  0.971698  0.585472  0.552976   8.649414   0.4158        Beta
# 1  0.953704  0.990741  0.916759  0.881933   0.632792   0.9761  Alpha Beta
# 2  0.917647  0.952941  0.862353  0.795423   9.506954   0.7529       Alpha
# 3  0.901235  0.938272  0.649630  0.628910  14.088815   0.7428  Alpha Beta
# 4  0.898230  0.964602  0.959602  0.931398   0.779426   0.9824  Alpha Beta
#
#    Sequence_Length  Contact_Order
# 0              106       0.119196
# 1              108       0.098140
# 2               85       0.051391
# 3              162       0.077646
# 4              226       0.073658

# %% [markdown]
# ### core/surface

# %% [markdown]
# #### recovery

# %%
# Specify the file paths
surface_file = './test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/surface_recoveries.csv'
core_file = './test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/core_recoveries.csv'

# Read the CSV files without headers
surface_data = pd.read_csv(surface_file, header=None, names=['Recovery'])
core_data = pd.read_csv(core_file, header=None, names=['Recovery'])

# Add a new column to differentiate the groups (Surface and Core)
surface_data['Group'] = 'Surface'
core_data['Group'] = 'Core'

# Concatenate the two DataFrames
combined_data = pd.concat([surface_data, core_data])

# Set up the figure
plt.figure(figsize=(8, 6))

# Create the boxplot
sns.boxplot(data=combined_data, x='Group', y='Recovery', palette='Set2')

# Set labels
plt.xlabel('Region')
plt.ylabel('Recovery')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery_core_surface.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/1644255417.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=combined_data, x='Group', y='Recovery', palette='Set2')

# %% [markdown]
# #### nssr

# %%
# Specify the file paths
surface_file = './test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/surface_nssrs.csv'
core_file = './test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/core_nssrs.csv'

# Read the CSV files without headers
surface_data = pd.read_csv(surface_file, header=None, names=['nssr'])
core_data = pd.read_csv(core_file, header=None, names=['nssr'])

# Add a new column to differentiate the groups (Surface and Core)
surface_data['Group'] = 'Surface'
core_data['Group'] = 'Core'

# Concatenate the two DataFrames
combined_data = pd.concat([surface_data, core_data])

# Set up the figure
plt.figure(figsize=(8, 6))

# Create the boxplot
sns.boxplot(data=combined_data, x='Group', y='nssr', palette='Set2')

# Set labels
plt.xlabel('Region')
plt.ylabel('nssr')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'nssr_core_surface.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/4156897175.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=combined_data, x='Group', y='nssr', palette='Set2')

# %% [markdown]
# ### cath class

# %% [markdown]
# #### recovery

# %%
# Define the custom order for x-axis sorting
order = ['Alpha', 'Beta', 'Alpha Beta', 'Other']

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot using seaborn
sns.boxplot(data=data, x='CATH_Class', y='Recovery', order=order, palette='Set2')

# Set labels and title
plt.xlabel('CATH Class')
plt.ylabel('Recovery')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery_cath_class.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/349202369.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='CATH_Class', y='Recovery', order=order, palette='Set2')

# %% [markdown]
# #### nssr

# %%
# Define the custom order for x-axis sorting
order = ['Alpha', 'Beta', 'Alpha Beta', 'Other']

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot using seaborn
sns.boxplot(data=data, x='CATH_Class', y='NSSR', order=order, palette='Set2')

# Set labels and title
plt.xlabel('CATH Class')
plt.ylabel('nssr')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'nssr_cath_class.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/659219355.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='CATH_Class', y='NSSR', order=order, palette='Set2')

# %% [markdown]
# #### plddt

# %%
# Define the custom order for x-axis sorting
order = ['Alpha', 'Beta', 'Alpha Beta', 'Other']

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot using seaborn
sns.boxplot(data=data, x='CATH_Class', y='pLDDT_CA', order=order, palette='Set2')

# Set labels and title
plt.xlabel('CATH Class')
plt.ylabel('pLDDT')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'plddt_cath_class.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2317774478.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='CATH_Class', y='pLDDT_CA', order=order, palette='Set2')

# %% [markdown]
# #### scTM

# %%
# Define the custom order for x-axis sorting
order = ['Alpha', 'Beta', 'Alpha Beta', 'Other']

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot using seaborn
sns.boxplot(data=data, x='CATH_Class', y='TMScore', order=order, palette='Set2')

# Set labels and title
plt.xlabel('CATH Class')
plt.ylabel('scTM')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'sctm_cath_class.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2424365353.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='CATH_Class', y='TMScore', order=order, palette='Set2')

# %% [markdown]
# ### size

# %%
# Determine the maximum value in the Sequence_Length column
max_length = data['Sequence_Length'].max()

# Create bin edges from 0 to the maximum sequence length with a step of 100
bins = np.arange(0, max_length + 100, 100)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create the histogram
sns.histplot(data['Sequence_Length'], bins=bins, kde=False, color='skyblue')

# Set labels and title
plt.xlabel('Sequence Length')
plt.ylabel('Frequency')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### recovery

# %%
# Define bin edges for sequence lengths (0, 100, 200, ..., max)
bins = np.arange(0, data['Sequence_Length'].max() + 100, 100)

# Bin the Sequence_Length column into categories (0-100, 100-200, etc.)
data['Length_Range'] = pd.cut(data['Sequence_Length'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned sequence lengths on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Length_Range', y='Recovery', palette='Set2')

# Set labels and title
plt.xlabel('Sequence Length Range')
plt.ylabel('Recovery')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery_size.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2311877090.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Length_Range', y='Recovery', palette='Set2')

# %% [markdown]
# #### nssr

# %%
# Define bin edges for sequence lengths (0, 100, 200, ..., max)
bins = np.arange(0, data['Sequence_Length'].max() + 100, 100)

# Bin the Sequence_Length column into categories (0-100, 100-200, etc.)
data['Length_Range'] = pd.cut(data['Sequence_Length'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned sequence lengths on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Length_Range', y='NSSR', palette='Set2')

# Set labels and title
plt.xlabel('Sequence Length Range')
plt.ylabel('nssr')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'nssr_size.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2742770585.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Length_Range', y='NSSR', palette='Set2')

# %% [markdown]
# #### plddt

# %%
# Define bin edges for sequence lengths (0, 100, 200, ..., max)
bins = np.arange(0, data['Sequence_Length'].max() + 100, 100)

# Bin the Sequence_Length column into categories (0-100, 100-200, etc.)
data['Length_Range'] = pd.cut(data['Sequence_Length'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned sequence lengths on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Length_Range', y='pLDDT_CA', palette='Set2')

# Set labels and title
plt.xlabel('Sequence Length Range')
plt.ylabel('pLDDT')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'plddt_size.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/3092561360.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Length_Range', y='pLDDT_CA', palette='Set2')

# %% [markdown]
# #### scTM

# %%
# Define bin edges for sequence lengths (0, 100, 200, ..., max)
bins = np.arange(0, data['Sequence_Length'].max() + 100, 100)

# Bin the Sequence_Length column into categories (0-100, 100-200, etc.)
data['Length_Range'] = pd.cut(data['Sequence_Length'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned sequence lengths on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Length_Range', y='TMScore', palette='Set2')

# Set labels and title
plt.xlabel('Sequence Length Range')
plt.ylabel('scTM')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'sctm_size.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/1713463326.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Length_Range', y='TMScore', palette='Set2')

# %% [markdown]
# ### structural complexity (contact order)

# %% [markdown]
# #### recovery

# %%
# scatterplot, deprecated
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import os

# Load data
contact_orders = np.load('./test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/contact_orders.npy')
recoveries = np.load('./test_results/SBC2-sum3-minlrdiv1-bs4-lr00002-epoch20-test/CATH4.2SurfProPiFoldDense/recoveries.npy')

# Create a DataFrame
data = pd.DataFrame({'Contact Orders': contact_orders, 'Recoveries': recoveries})

# LOESS fit
frac = 0.3
lowess = sm.nonparametric.lowess(data['Recoveries'], data['Contact Orders'], frac=frac)
x_fit = lowess[:, 0]
y_fit = lowess[:, 1]

# Bootstrapping to calculate confidence intervals
n_bootstraps = 1000
predictions = np.zeros((n_bootstraps, len(x_fit)))

for i in range(n_bootstraps):
    # Resample data with replacement
    bootstrap_sample = data.sample(frac=1, replace=True)
    lowess_bs = sm.nonparametric.lowess(bootstrap_sample['Recoveries'], bootstrap_sample['Contact Orders'], frac=frac)
    predictions[i, :] = lowess_bs[:, 1]

# Calculate confidence intervals
ci_lower = np.percentile(predictions, 2.5, axis=0)
ci_upper = np.percentile(predictions, 97.5, axis=0)

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Contact Orders', y='Recoveries', data=data, alpha=0.5)

# Plot LOESS curve
plt.plot(x_fit, y_fit, color='red', label='LOESS Fit')

# Plot confidence intervals
plt.fill_between(x_fit, ci_lower, ci_upper, color='red', alpha=0.2, label='95% CI')

# Labels and title
plt.xlabel('Contact Order')
plt.ylabel('Recovery')
# plt.title('LOESS Fit with Varying Confidence Intervals')
plt.legend()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery_contact_order.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))

# %%
# Define bin edges for Contact_Order (0, 0.1, 0.2, ..., max)
bins = np.arange(0, data['Contact_Order'].max() + 0.05, 0.05)

# Bin the Contact_Order column into categories (0-0.1, 0.1-0.2, etc.)
data['Contact_Order_Range'] = pd.cut(data['Contact_Order'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned contact order on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Contact_Order_Range', y='Recovery', palette='Set2')

# Set labels and title
plt.xlabel('Contact Order Range')
plt.ylabel('Recovery')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'recovery_contact_order.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2187387203.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Contact_Order_Range', y='Recovery', palette='Set2')

# %% [markdown]
# #### nssr

# %%
# Define bin edges for Contact_Order (0, 0.1, 0.2, ..., max)
bins = np.arange(0, data['Contact_Order'].max() + 0.05, 0.05)

# Bin the Contact_Order column into categories (0-0.1, 0.1-0.2, etc.)
data['Contact_Order_Range'] = pd.cut(data['Contact_Order'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned contact order on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Contact_Order_Range', y='NSSR', palette='Set2')

# Set labels and title
plt.xlabel('Contact Order Range')
plt.ylabel('nssr')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'nssr_contact_order.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2930644860.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Contact_Order_Range', y='NSSR', palette='Set2')

# %% [markdown]
# #### plddt

# %%
# Define bin edges for Contact_Order (0, 0.1, 0.2, ..., max)
bins = np.arange(0, data['Contact_Order'].max() + 0.05, 0.05)

# Bin the Contact_Order column into categories (0-0.1, 0.1-0.2, etc.)
data['Contact_Order_Range'] = pd.cut(data['Contact_Order'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned contact order on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Contact_Order_Range', y='pLDDT_CA', palette='Set2')

# Set labels and title
plt.xlabel('Contact Order Range')
plt.ylabel('pLDDT')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'plddt_contact_order.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/1653084521.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Contact_Order_Range', y='pLDDT_CA', palette='Set2')

# %% [markdown]
# #### scTM

# %%
# Define bin edges for Contact_Order (0, 0.1, 0.2, ..., max)
bins = np.arange(0, data['Contact_Order'].max() + 0.05, 0.05)

# Bin the Contact_Order column into categories (0-0.1, 0.1-0.2, etc.)
data['Contact_Order_Range'] = pd.cut(data['Contact_Order'], bins=bins, right=False)

# Set up the figure
plt.figure(figsize=(10, 6))

# Create a boxplot with binned contact order on the x-axis and recovery on the y-axis
sns.boxplot(data=data, x='Contact_Order_Range', y='TMScore', palette='Set2')

# Set labels and title
plt.xlabel('Contact Order Range')
plt.ylabel('scTM')

# Show the plot
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'sctm_contact_order.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))
# Out:
# /tmp/ipykernel_3641206/2224646724.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Contact_Order_Range', y='TMScore', palette='Set2')

# %% [markdown]
# ### residue-level metrics

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data provided (formatted into a dictionary for easier conversion to DataFrame)
data = {
    'A': {
        'accuracy': 0.9849, 'f1': 0.9045, 'precision': 0.8867, 'recall': 0.9230
    },
    'C': {
        'accuracy': 0.9978, 'f1': 0.9144, 'precision': 0.9404, 'recall': 0.8898
    },
    'D': {
        'accuracy': 0.9558, 'f1': 0.5899, 'precision': 0.6747, 'recall': 0.5241
    },
    'E': {
        'accuracy': 0.9502, 'f1': 0.6915, 'precision': 0.6284, 'recall': 0.7686
    },
    'F': {
        'accuracy': 0.9925, 'f1': 0.9138, 'precision': 0.9368, 'recall': 0.8920
    },
    'G': {
        'accuracy': 0.9934, 'f1': 0.9507, 'precision': 0.9351, 'recall': 0.9668
    },
    'H': {
        'accuracy': 0.9965, 'f1': 0.9227, 'precision': 0.9495, 'recall': 0.8974
    },
    'I': {
        'accuracy': 0.9898, 'f1': 0.9122, 'precision': 0.9235, 'recall': 0.9012
    },
    'K': {
        'accuracy': 0.9890, 'f1': 0.9109, 'precision': 0.9023, 'recall': 0.9197
    },
    'L': {
        'accuracy': 0.9809, 'f1': 0.8986, 'precision': 0.8722, 'recall': 0.9266
    },
    'M': {
        'accuracy': 0.9932, 'f1': 0.8357, 'precision': 0.8836, 'recall': 0.7927
    },
    'N': {
        'accuracy': 0.9705, 'f1': 0.6425, 'precision': 0.6538, 'recall': 0.6316
    },
    'P': {
        'accuracy': 0.9961, 'f1': 0.9559, 'precision': 0.9297, 'recall': 0.9836
    },
    'Q': {
        'accuracy': 0.9731, 'f1': 0.6419, 'precision': 0.6601, 'recall': 0.6246
    },
    'R': {
        'accuracy': 0.9923, 'f1': 0.9218, 'precision': 0.9446, 'recall': 0.9002
    },
    'S': {
        'accuracy': 0.9901, 'f1': 0.9151, 'precision': 0.9163, 'recall': 0.9139
    },
    'T': {
        'accuracy': 0.9909, 'f1': 0.9156, 'precision': 0.9279, 'recall': 0.9036
    },
    'V': {
        'accuracy': 0.9866, 'f1': 0.9084, 'precision': 0.9045, 'recall': 0.9123
    },
    'W': {
        'accuracy': 0.9981, 'f1': 0.9246, 'precision': 0.9612, 'recall': 0.8906
    },
    'Y': {
        'accuracy': 0.9937, 'f1': 0.9097, 'precision': 0.9341, 'recall': 0.8866
    }
}

# Convert to DataFrame
df = pd.DataFrame(data).T.reset_index()
df.columns = ['Amino Acid', 'Accuracy', 'F1', 'Precision', 'Recall']

# Melt the DataFrame for seaborn
df_melted = df.melt(id_vars='Amino Acid', var_name='Metric', value_name='Value')

# Set up the figure
plt.figure(figsize=(12, 8))

# Create bar plots for each metric using seaborn
sns.barplot(data=df_melted, x='Amino Acid', y='Value', hue='Metric', palette='viridis')

# Set x-tick labels without rotation
plt.xticks(rotation=0)
plt.legend(title='Metric', loc='upper left', bbox_to_anchor=(1, 1))  # Move legend to the right
plt.tight_layout()
# plt.show()
# Path to save the figure
save_path = './figures/cath42'
file_name = 'residue_level.png'

# Create the directory if it doesn't exist
if not os.path.exists(save_path):
    os.makedirs(save_path)
plt.savefig(os.path.join(save_path, file_name))

# %%
# full: 0.8803263306617737
# w.o. correspondence: 0.42445188760757446
# w.o. structure feature: 0.8360046148300171
# w.o. edge feature: 0.8718589544296265
# w.o. node feature: 0.8472650051116943
# w.o. biochem. feature: 0.3220404386520386
# w.o. hydrophobicity: 0.2150287926197052
# w.o. charge: 0.8264081478118896
